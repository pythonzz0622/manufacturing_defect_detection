# %%
import utils

# %%
visualtool = utils.visualization.VisualTool(coco_gt_path = '../info/coco.json' )
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!

# %%
visualtool.coco_cvt
# Out:
# over : [1, 6, 9, 10, 11, 14, 15, 16, 17, 18, 21, 27, 31, 33, 38, 40, 43, 44, 45, 46, 50, 53, 54, 58, 68, 69, 70, 72, 74, 77, 79, 81, 82, 84, 90, 92, 95, 96, 97, 98, 100, 102, 103, 106, 108, 109, 110, 113, 114, 116, 118, 120, 127, 129, 130, 132, 134, 135, 141, 146, 147, 148, 149, 150, 151, 156, 161, 162, 164, 165, 170, 174, 175, 176, 177, 178, 179, 182, 185, 186, 191, 198, 199, 200, 201, 205, 206, 207, 210, 211, 214, 216, 217, 218, 220, 222, 224, 229, 231, 232, 237, 240, 241, 246, 247, 248, 251, 256, 258, 260, 263, 265, 266, 267, 269, 270, 272, 275, 276, 280, 284, 285, 286, 288, 291, 292, 293, 294, 295, 296, 297, 298, 301, 302, 303, 306, 307, 310, 311, 312, 314, 318, 321, 322, 325, 327, 328, 329, 330, 331, 332, 336, 337, 339, 340, 343, 344, 346, 348, 349, 354, 357, 358, 359, 362, 365, 368, 373, 374, 375, 376, 380, 381, 382, 386, 387, 389, 393, 394, 395, 396, 399, 400, 401, 402, 403, 406, 407, 409, 411, 417, 420, 424, 425, 428, 431, 432, 433, 438, 439, 440, 441, 442, 445, 447, 449, 452
# ...

# %%
visualtool.visual(26)

# %%
visualtool.coco_cvt.img_annos(513)
# Out:
# {'file_name': 'defect/221221_151938_0000027068_CAM1_NORMAL_OK.jpg',
#  'ground_truth': {'bbox': [[451, 295, 39, 42]], 'category_id': [1]},
#  'preds': {'bbox': [[286.5861511230469,
#     272.6438903808594,
#     185.59808349609375,
#     81.24322509765625],
#    [760.6541137695312, 0.0, 23.34588623046875, 20.565105438232422]],
#   'category_id': [1, 2],
#   'score': [0.682578980922699, 0.5937095880508423]}}

# %%
visualtool.PR_plot()
# Out:
#      precision    recall     category  confidence  f1_score
# 0     0.113788  1.000000         over        0.00  0.204327
# 1     0.113788  0.653846         over        0.01  0.193843
# 2     0.113788  0.653846         over        0.02  0.193843
# 3     0.113788  0.653846         over        0.03  0.193843
# 4     0.113788  0.653846         over        0.04  0.193843
# ..         ...       ...          ...         ...       ...
# 298   1.000000  0.000000  non-welding        0.96  0.000000
# 299   1.000000  0.000000  non-welding        0.97  0.000000
# 300   1.000000  0.000000  non-welding        0.98  0.000000
# 301   1.000000  0.000000  non-welding        0.99  0.000000
# 302   1.000000  0.000000  non-welding        1.00  0.000000
#
# [303 rows x 5 columns]

# %%
visualtool.conf_vs()

# %%
coco_cvt = utils.type_converter.COCO_converter(coco_gt_path = '../info/test.json' , coco_pred_path = 'result.json')
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.33s).
# Accumulating evaluation results...
# DONE (t=0.19s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.406
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.321
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.235
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.344
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.353
# ...

# %%
coco_cvt.PRF_df()
# Out:
#      precision    recall     category  confidence  f1_score
# 0     0.113788  1.000000         over        0.00  0.204327
# 1     0.113788  0.653846         over        0.01  0.193843
# 2     0.113788  0.653846         over        0.02  0.193843
# 3     0.113788  0.653846         over        0.03  0.193843
# 4     0.113788  0.653846         over        0.04  0.193843
# ..         ...       ...          ...         ...       ...
# 298   1.000000  0.000000  non-welding        0.96  0.000000
# 299   1.000000  0.000000  non-welding        0.97  0.000000
# 300   1.000000  0.000000  non-welding        0.98  0.000000
# 301   1.000000  0.000000  non-welding        0.99  0.000000
# 302   1.000000  0.000000  non-welding        1.00  0.000000
#
# [303 rows x 5 columns]
